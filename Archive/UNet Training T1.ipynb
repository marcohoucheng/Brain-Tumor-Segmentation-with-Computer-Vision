# %% [markdown]
# # U-Net
#
# - Crop training images according to ground truth tumour area
# - Standardise and resize
# - One Hot Encoding

# %%
N_EPOCHS = 50
batch_size = 64
scan_type = 'T1'

# %% [markdown]
# ## Setup

# %%
import os, random, time
import numpy as np
import pandas as pd
import nibabel as nib
import cv2
import matplotlib.pyplot as plt

# Pytorch functions
import torch
# Neural network layers
import torch.nn as nn
import torch.nn.functional as F
# Optimizer
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, Subset
# Torchvision library
from torchvision import transforms

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# For results
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from torchsummary import summary

from utilities import *

# %%
# Device configuration
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
   device = torch.device('mps')
else:
    device = torch.device('cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# mps

# %%
def set_seed(seed, use_cuda = True, use_mps = False):
    """
    Set SEED for PyTorch reproducibility
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if use_cuda:
        torch.cuda.manual_seed_all(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if use_mps:
        torch.mps.manual_seed(seed)

SEED = 44

USE_SEED = True

if USE_SEED:
    set_seed(SEED, torch.cuda.is_available(), torch.backends.mps.is_available())

# %%
train_images = np.sort([image for image in os.listdir(os.path.join('./BraTS/BraTS2021_Training_Data_2D_Unet', 'train', str(scan_type.lower()))) if image != '.DS_Store'])

# %% [markdown]
# ## Define Custom Dataset

# %%
class BraTSDataset(Dataset):
    def __init__(self, image_path = './BraTS/BraTS2021_Training_Data_2D_Unet', subset = 'train', transform = None):
        'Initialisation'
        self.image_path = os.path.join(image_path, subset)
        self.image_names = np.sort([image for image in os.listdir(os.path.join(self.image_path, str(scan_type.lower()))) if image != '.DS_Store'])
        self.labels_names = np.sort([image for image in os.listdir(os.path.join(self.image_path, 'seg')) if image != '.DS_Store'])
        self.transform = transform
    
    def get_id(self, index):
        return self.image_names[index]

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.image_names)

    def __getitem__(self, index):
        'Generates one sample of data'

        # Select sample
        image_name = self.image_names[index]
        label_name = self.labels_names[index]
        
        path_img = os.path.join(self.image_path, str(scan_type.lower()), image_name)
        path_label = os.path.join(self.image_path, 'seg', label_name)
        image = np.load(path_img).astype(np.float32)
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
class OneHotLabel(object):
    def __call__(self, sample):
        image, label = sample
        new_label = np.zeros((64,64,4)) # 0,1,2,4
        for i, l in enumerate([0,1,2,4]):
            new_label[:,:,i] = (label == l)
        return image, new_label

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""
    def __call__(self, sample):
        image, label = sample
        image = np.float32(image)
        label = np.float32(label)

        # swap channel axis because
        # numpy image: H x W x C
        # torch image: C x H x W
        new_label = label.transpose((2, 0, 1))
        return torch.from_numpy(image), torch.from_numpy(new_label)

# %%
dataset_train = BraTSDataset(transform = transforms.Compose([OneHotLabel(), ToTensor()]))
dataset_valid = BraTSDataset(subset = 'valid', transform = transforms.Compose([OneHotLabel(), ToTensor()]))
dataset_test = BraTSDataset(subset = 'test', transform = transforms.Compose([OneHotLabel(), ToTensor()]))

# %%
# Create the subset DataLoader
train_dataloader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(dataset_valid, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

# %%
class UNet(nn.Module):
    def __init__(self):
        super().__init__()

        ## Input is 32 x 32 x 1
        ## Output is 32 x 32 x 4
        
        # Encoder
        # In the encoder, convolutional layers with the Conv2d function are used to extract features from the input image. 
        # Each block in the encoder consists of two convolutional layers followed by a max-pooling layer, with the exception of the last block which does not include a max-pooling layer.
        # -------
        # input: 572x572x3 32 x 32 x 1
        self.e11 = nn.Conv2d(1, 64, kernel_size=3, padding=1) # output: 30x30x64
        self.e12 = nn.Conv2d(64, 64, kernel_size=3, padding=1) # output: 568x568x64
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) # output: 284x284x64

        # input: 284x284x64
        self.e21 = nn.Conv2d(64, 128, kernel_size=3, padding=1) # output: 282x282x128
        self.e22 = nn.Conv2d(128, 128, kernel_size=3, padding=1) # output: 280x280x128
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) # output: 140x140x128

        # input: 140x140x128
        self.e31 = nn.Conv2d(128, 256, kernel_size=3, padding=1) # output: 138x138x256
        self.e32 = nn.Conv2d(256, 256, kernel_size=3, padding=1) # output: 136x136x256
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) # output: 68x68x256

        # input: 68x68x256
        self.e41 = nn.Conv2d(256, 512, kernel_size=3, padding=1) # output: 66x66x512
        self.e42 = nn.Conv2d(512, 512, kernel_size=3, padding=1) # output: 64x64x512
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2) # output: 32x32x512

        # input: 32x32x512
        self.e51 = nn.Conv2d(512, 1024, kernel_size=3, padding=1) # output: 30x30x1024
        self.e52 = nn.Conv2d(1024, 1024, kernel_size=3, padding=1) # output: 28x28x1024


        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.d11 = nn.Conv2d(1024, 512, kernel_size=3, padding=1)
        self.d12 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.d21 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.d22 = nn.Conv2d(256, 256, kernel_size=3, padding=1)

        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.d31 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.d32 = nn.Conv2d(128, 128, kernel_size=3, padding=1)

        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.d41 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.d42 = nn.Conv2d(64, 64, kernel_size=3, padding=1)

        # Output layer
        self.outconv = nn.Conv2d(64, 4, kernel_size=1)

    def forward(self, x):
        x = x.view(x.shape[0], 1, 64, 64)
        # Encoder
        xe11 = F.relu(self.e11(x))
        xe12 = F.relu(self.e12(xe11))
        xp1 = self.pool1(xe12)

        xe21 = F.relu(self.e21(xp1))
        xe22 = F.relu(self.e22(xe21))
        xp2 = self.pool2(xe22)

        xe31 = F.relu(self.e31(xp2))
        xe32 = F.relu(self.e32(xe31))
        xp3 = self.pool3(xe32)

        xe41 = F.relu(self.e41(xp3))
        xe42 = F.relu(self.e42(xe41))
        xp4 = self.pool4(xe42)

        xe51 = F.relu(self.e51(xp4))
        xe52 = F.relu(self.e52(xe51))
        
        # Decoder
        xu1 = self.upconv1(xe52)
        xu11 = torch.cat([xu1, xe42], dim=1)
        xd11 = F.relu(self.d11(xu11))
        xd12 = F.relu(self.d12(xd11))

        xu2 = self.upconv2(xd12)
        xu22 = torch.cat([xu2, xe32], dim=1)
        xd21 = F.relu(self.d21(xu22))
        xd22 = F.relu(self.d22(xd21))

        xu3 = self.upconv3(xd22)
        xu33 = torch.cat([xu3, xe22], dim=1)
        xd31 = F.relu(self.d31(xu33))
        xd32 = F.relu(self.d32(xd31))

        xu4 = self.upconv4(xd32)
        xu44 = torch.cat([xu4, xe12], dim=1)
        xd41 = F.relu(self.d41(xu44))
        xd42 = F.relu(self.d42(xd41))

        # Output layer
        out = self.outconv(xd42)

        return out

# %%
model = UNet().to(device)

print(f"The model has {count_parameters(model):,} trainable parameters.")
# Out:
# The model has 31,030,788 trainable parameters.

# %%
# Loss
# criterion = nn.CrossEntropyLoss() # Softmax + CrossEntropy
# criterion = nn.BCELoss()
criterion = torch.nn.BCEWithLogitsLoss()
criterion = criterion.to(device)

# Optim
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-3)

# %%
train_losses, train_accs, valid_losses, valid_accs,\
    train_losses_batch, train_accs_batch, valid_losses_batch, valid_accs_batch = model_training(N_EPOCHS,
                                                                                    model,
                                                                                    train_dataloader,
                                                                                    val_dataloader,
                                                                                    optimizer,
                                                                                    criterion,
                                                                                    device,
                                                                                    f'./models/UNet_{scan_type}.pt')
# Out:
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 1/50 -- Epoch Time: 500.25 s
# Train -- Loss: 0.389, Acc: 81.55%
# Val -- Loss: 0.349, Acc: 84.18%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 2/50 -- Epoch Time: 500.83 s
# Train -- Loss: 0.342, Acc: 84.24%
# Val -- Loss: 0.340, Acc: 84.45%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 3/50 -- Epoch Time: 503.78 s
# Train -- Loss: 0.335, Acc: 84.56%
# Val -- Loss: 0.339, Acc: 84.44%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 4/50 -- Epoch Time: 501.98 s
# Train -- Loss: 0.330, Acc: 84.83%
# Val -- Loss: 0.338, Acc: 84.66%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 5/50 -- Epoch Time: 500.81 s
# Train -- Loss: 0.326, Acc: 85.02%
# Val -- Loss: 0.328, Acc: 85.02%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 6/50 -- Epoch Time: 501.54 s
# Train -- Loss: 0.321, Acc: 85.24%
# Val -- Loss: 0.322, Acc: 85.31%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 7/50 -- Epoch Time: 500.09 s
# Train -- Loss: 0.318, Acc: 85.40%
# Val -- Loss: 0.321, Acc: 85.41%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 8/50 -- Epoch Time: 501.51 s
# Train -- Loss: 0.315, Acc: 85.54%
# Val -- Loss: 0.321, Acc: 85.31%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 9/50 -- Epoch Time: 500.44 s
# Train -- Loss: 0.314, Acc: 85.62%
# Val -- Loss: 0.318, Acc: 85.64%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 10/50 -- Epoch Time: 500.26 s
# Train -- Loss: 0.312, Acc: 85.72%
# Val -- Loss: 0.319, Acc: 85.38%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 11/50 -- Epoch Time: 496.34 s
# Train -- Loss: 0.311, Acc: 85.78%
# Val -- Loss: 0.317, Acc: 85.62%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 12/50 -- Epoch Time: 498.28 s
# Train -- Loss: 0.310, Acc: 85.84%
# Val -- Loss: 0.315, Acc: 85.82%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 13/50 -- Epoch Time: 504.37 s
# Train -- Loss: 0.308, Acc: 85.92%
# Val -- Loss: 0.315, Acc: 85.67%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 14/50 -- Epoch Time: 502.81 s
# Train -- Loss: 0.307, Acc: 85.98%
# Val -- Loss: 0.312, Acc: 85.86%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 15/50 -- Epoch Time: 499.46 s
# Train -- Loss: 0.307, Acc: 86.01%
# Val -- Loss: 0.311, Acc: 85.98%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 16/50 -- Epoch Time: 496.48 s
# Train -- Loss: 0.306, Acc: 86.05%
# Val -- Loss: 0.311, Acc: 85.95%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 17/50 -- Epoch Time: 498.32 s
# Train -- Loss: 0.305, Acc: 86.11%
# Val -- Loss: 0.309, Acc: 86.03%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 18/50 -- Epoch Time: 497.10 s
# Train -- Loss: 0.304, Acc: 86.17%
# Val -- Loss: 0.309, Acc: 86.01%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 19/50 -- Epoch Time: 496.18 s
# Train -- Loss: 0.303, Acc: 86.21%
# Val -- Loss: 0.308, Acc: 86.10%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 20/50 -- Epoch Time: 497.34 s
# Train -- Loss: 0.302, Acc: 86.25%
# Val -- Loss: 0.312, Acc: 86.06%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 21/50 -- Epoch Time: 497.83 s
# Train -- Loss: 0.301, Acc: 86.30%
# Val -- Loss: 0.307, Acc: 86.20%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 22/50 -- Epoch Time: 495.89 s
# Train -- Loss: 0.301, Acc: 86.33%
# Val -- Loss: 0.307, Acc: 86.16%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 23/50 -- Epoch Time: 492.50 s
# Train -- Loss: 0.300, Acc: 86.36%
# Val -- Loss: 0.307, Acc: 86.24%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 24/50 -- Epoch Time: 503.63 s
# Train -- Loss: 0.299, Acc: 86.40%
# Val -- Loss: 0.305, Acc: 86.30%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 25/50 -- Epoch Time: 498.76 s
# Train -- Loss: 0.299, Acc: 86.43%
# Val -- Loss: 0.310, Acc: 86.11%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 26/50 -- Epoch Time: 493.57 s
# Train -- Loss: 0.299, Acc: 86.45%
# Val -- Loss: 0.306, Acc: 86.18%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 27/50 -- Epoch Time: 503.05 s
# Train -- Loss: 0.298, Acc: 86.48%
# Val -- Loss: 0.305, Acc: 86.31%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 28/50 -- Epoch Time: 503.96 s
# Train -- Loss: 0.298, Acc: 86.50%
# Val -- Loss: 0.304, Acc: 86.31%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 29/50 -- Epoch Time: 498.85 s
# Train -- Loss: 0.297, Acc: 86.53%
# Val -- Loss: 0.305, Acc: 86.31%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 30/50 -- Epoch Time: 508.39 s
# Train -- Loss: 0.297, Acc: 86.56%
# Val -- Loss: 0.304, Acc: 86.31%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 31/50 -- Epoch Time: 501.30 s
# Train -- Loss: 0.296, Acc: 86.56%
# Val -- Loss: 0.304, Acc: 86.30%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 32/50 -- Epoch Time: 499.69 s
# Train -- Loss: 0.296, Acc: 86.59%
# Val -- Loss: 0.302, Acc: 86.36%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 33/50 -- Epoch Time: 496.82 s
# Train -- Loss: 0.296, Acc: 86.61%
# Val -- Loss: 0.305, Acc: 86.36%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 34/50 -- Epoch Time: 493.41 s
# Train -- Loss: 0.295, Acc: 86.62%
# Val -- Loss: 0.304, Acc: 86.38%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 35/50 -- Epoch Time: 503.19 s
# Train -- Loss: 0.295, Acc: 86.64%
# Val -- Loss: 0.302, Acc: 86.43%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 36/50 -- Epoch Time: 499.39 s
# Train -- Loss: 0.295, Acc: 86.65%
# Val -- Loss: 0.307, Acc: 86.16%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 37/50 -- Epoch Time: 495.43 s
# Train -- Loss: 0.295, Acc: 86.67%
# Val -- Loss: 0.300, Acc: 86.53%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 38/50 -- Epoch Time: 495.88 s
# Train -- Loss: 0.294, Acc: 86.69%
# Val -- Loss: 0.304, Acc: 86.33%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 39/50 -- Epoch Time: 498.64 s
# Train -- Loss: 0.294, Acc: 86.69%
# Val -- Loss: 0.301, Acc: 86.51%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 40/50 -- Epoch Time: 504.05 s
# Train -- Loss: 0.294, Acc: 86.69%
# Val -- Loss: 0.305, Acc: 86.09%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 41/50 -- Epoch Time: 504.47 s
# Train -- Loss: 0.294, Acc: 86.71%
# Val -- Loss: 0.302, Acc: 86.49%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 42/50 -- Epoch Time: 504.73 s
# Train -- Loss: 0.293, Acc: 86.73%
# Val -- Loss: 0.301, Acc: 86.46%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 43/50 -- Epoch Time: 497.50 s
# Train -- Loss: 0.293, Acc: 86.74%
# Val -- Loss: 0.303, Acc: 86.49%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 44/50 -- Epoch Time: 491.12 s
# Train -- Loss: 0.293, Acc: 86.76%
# Val -- Loss: 0.303, Acc: 86.27%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 45/50 -- Epoch Time: 499.69 s
# Train -- Loss: 0.293, Acc: 86.76%
# Val -- Loss: 0.303, Acc: 86.27%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 46/50 -- Epoch Time: 499.88 s
# Train -- Loss: 0.292, Acc: 86.77%
# Val -- Loss: 0.300, Acc: 86.53%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 47/50 -- Epoch Time: 504.51 s
# Train -- Loss: 0.292, Acc: 86.78%
# Val -- Loss: 0.302, Acc: 86.50%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 48/50 -- Epoch Time: 493.75 s
# Train -- Loss: 0.292, Acc: 86.79%
# Val -- Loss: 0.301, Acc: 86.58%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 49/50 -- Epoch Time: 497.08 s
# Train -- Loss: 0.292, Acc: 86.78%
# Val -- Loss: 0.299, Acc: 86.60%
# 100.0 % loaded in this epoch for training
#
# 100.0 % loaded in this epoch for evaluation.
#
# ---------------------------------
#
# Epoch: 50/50 -- Epoch Time: 500.45 s
# Train -- Loss: 0.292, Acc: 86.80%
# Val -- Loss: 0.308, Acc: 86.11%

# %%
os.makedirs('./results', exist_ok=True)

pd.DataFrame({
    'Train Loss': train_losses,
    'Train Acc': train_accs,
    'Valid Loss': valid_losses,
    'Valid Acc': valid_accs
}).to_csv(f'./results/Unet_{scan_type}.csv', index = False)

# %%
stacked_df = pd.concat([pd.DataFrame(pd.DataFrame(train_losses_batch).values.flatten(), columns=['Train Loss']),
                        pd.DataFrame(pd.DataFrame(train_accs_batch).values.flatten(), columns=['Train Acc']),
                        pd.DataFrame(pd.DataFrame(valid_losses_batch).values.flatten(), columns=['Valid Loss']),
                        pd.DataFrame(pd.DataFrame(valid_accs_batch).values.flatten(), columns=['Valid Acc'])], axis=1)
stacked_df.to_csv(f'./results/Unet_{scan_type}_batch.csv', index = False)

# %%
plot_results(N_EPOCHS, train_losses, train_accs, valid_losses, valid_accs)

# %%
# Plot results
plt.figure(figsize=(20, 6))
_ = plt.subplot(1,2,1)
plt.plot(np.arange(len(stacked_df['Train Loss']))+1, stacked_df['Train Loss'], linewidth=3)
plt.plot(np.arange(len(stacked_df['Valid Loss']))+1, stacked_df['Valid Loss'], linewidth=3)
_ = plt.legend(['Train', 'Validation'])
plt.grid('on'), plt.xlabel('Epoch'), plt.ylabel('Loss')

_ = plt.subplot(1,2,2)
plt.plot(np.arange(len(stacked_df['Train Acc']))+1, stacked_df['Train Acc'], linewidth=3)
plt.plot(np.arange(len(stacked_df['Valid Acc']))+1, stacked_df['Valid Acc'], linewidth=3)
_ = plt.legend(['Train', 'Validation'])
plt.grid('on'), plt.xlabel('Epoch'), plt.ylabel('Accuracy')

plt.show()

# %%
# Plot results
plt.figure(figsize=(20, 6))
_ = plt.subplot(1,2,1)
plt.plot(np.arange(4000)+1, stacked_df['Train Loss'][:4000], linewidth=3)
plt.plot(np.arange(4000)+1, stacked_df['Valid Loss'][:4000], linewidth=3)
plt.ylim(0,1)
_ = plt.legend(['Train', 'Validation'])
plt.grid('on'), plt.xlabel('Epoch'), plt.ylabel('Loss')

_ = plt.subplot(1,2,2)
plt.plot(np.arange(200)+1, stacked_df['Train Acc'][:200], linewidth=3)
plt.plot(np.arange(200)+1, stacked_df['Valid Acc'][:200], linewidth=3)
_ = plt.legend(['Train', 'Validation'])
plt.grid('on'), plt.xlabel('Epoch'), plt.ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Prediction

# %%
# Change the print options for PyTorch tensors
torch.set_printoptions(threshold=10_000)
# Reset print options to default if desired
torch.set_printoptions(threshold=1000)

# %%
model.load_state_dict(torch.load(f'./models/Unet_{scan_type}.pt'))
model.to(device)

# %%
labels, preds = predict(model, test_dataloader, device)

# %%
# folders = [folder for folder in os.listdir(os.path.join('./BraTS', 'BraTS2021_Training_Data')) if folder != '.DS_Store']
# def index_converter(index):
#     return index // 155, index % 155 # image_idx, layer_idx

# %%
# dataset_size = len(folders)
# dataset_indices = list(range(dataset_size))

# train_indices, test_indices = train_test_split(dataset_indices, test_size=0.1, random_state=SEED)
# train_indices, val_indices = train_test_split(train_indices, test_size=0.22, random_state=SEED)

# tmp_list = [[],[],[]]
# for i, ind_list in enumerate([train_indices, val_indices, test_indices]):
#     for ind in ind_list:
#         for j in range(155):
#             tmp_list[i].append(ind*155 + j)
# train_indices, val_indices, test_indices = tmp_list

# %% [markdown]
# For example, we want to see the $231^{st}$ test data

# %%
img = 230 # id in test set

# %%
# image_id, slice_no = index_converter(test_indices[img])
# print(f"Image ID: {image_id}, Slice No: {slice_no}")
# Out:
# Image ID: 481, Slice No: 75

# %%
pred = torch.argmax(preds[img], dim=0)
label = torch.argmax(labels[img], dim=0)

# Re-label class '3' to '4'
pred = torch.where(pred == 3, torch.tensor(4), pred)
label = torch.where(label == 3, torch.tensor(4), label)

# %%
plt.imshow(pred)

# %%
plt.imshow(label)

# %% [markdown]
# We can see the original data and their cropped area

# %%
image_id, slice_no = [os.path.splitext(dataset_test.get_id(img))[0].split('_')[i] for i in [1,3]]

# %%
crop_region = np.load(f'./BraTS/BraTS2021_Training_Data_2D_Unet/test/cropped_area/BraTS2021_{str(image_id).zfill(5)}_area_{slice_no}.npy')
crop_region
# Out:
# array([27, 52, 12, 37])

# %%
org_image = np.load(f'./BraTS/BraTS2021_Training_Data_2D/BraTS2021_{str(image_id).zfill(5)}/{scan_type.lower()}/BraTS2021_{str(image_id).zfill(5)}_{scan_type.lower()}_{slice_no}.npy')
org_label = np.load(f'./BraTS/BraTS2021_Training_Data_2D/BraTS2021_{str(image_id).zfill(5)}/seg/BraTS2021_{str(image_id).zfill(5)}_seg_{slice_no}.npy')

# %%
plt.imshow(org_image)

# %%
plt.imshow(org_label)
