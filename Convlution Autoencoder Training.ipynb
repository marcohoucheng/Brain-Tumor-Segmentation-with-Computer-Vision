# %%
N_EPOCHS = 40
batch_size = 64

# %% [markdown]
# # Flair

# %% [markdown]
# ## Setup

# %%
import os, random, time
import numpy as np
import pandas as pd
import nibabel as nib
import cv2
import matplotlib.pyplot as plt

# Pytorch functions
import torch
# Neural network layers
import torch.nn as nn
import torch.nn.functional as F
# Optimizer
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, Subset
# Torchvision library
from torchvision import transforms

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# For results
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from torchsummary import summary

from utilities import *

# %%
# Device configuration
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
   device = torch.device('mps')
else:
    device = torch.device('cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# mps

# %%
def set_seed(seed, use_cuda = True, use_mps = False):
    """
    Set SEED for PyTorch reproducibility
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if use_cuda:
        torch.cuda.manual_seed_all(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if use_mps:
        torch.mps.manual_seed(seed)

SEED = 44

USE_SEED = True

if USE_SEED:
    set_seed(SEED, torch.cuda.is_available(), torch.backends.mps.is_available())

# %% [markdown]
# ## Define Custom Dataset

# %%
class BraTSDataset_Flair(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 'flair', file_name + '_flair_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
class BinariseLabel(object):
    def __call__(self, sample):
        image, label = sample
        new_label = np.sign(label)
        return image, new_label

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""
    def __call__(self, sample):
        image, label = sample

        # numpy image: H x W x C
        # torch image: C x H x W
        # image = image.transpose((2, 0, 1))
        return torch.from_numpy(image), torch.from_numpy(label)

# %%
dataset_Flair = BraTSDataset_Flair(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %% [markdown]
# ## Train Test Split

# %%
dataset_size = int(len(dataset_Flair)/155)
dataset_indices = list(range(dataset_size))

train_indices, test_indices = train_test_split(dataset_indices, test_size=0.1, random_state=SEED)
train_indices, val_indices = train_test_split(train_indices, test_size=0.22, random_state=SEED)

tmp_list = [[],[],[]]
for i, ind_list in enumerate([train_indices, val_indices, test_indices]):
    for ind in ind_list:
        for j in range(155):
            tmp_list[i].append(ind*155 + j)
train_indices, val_indices, test_indices = tmp_list

train_subset_Flair = Subset(dataset_Flair, train_indices)
val_subset_Flair = Subset(dataset_Flair, val_indices)
test_subset_Flair = Subset(dataset_Flair, test_indices)

# Create the subset DataLoader
train_dataloader_Flair = DataLoader(train_subset_Flair, batch_size=batch_size, shuffle=True)
val_dataloader_Flair = DataLoader(val_subset_Flair, batch_size=batch_size, shuffle=True)
test_dataloader_Flair = DataLoader(test_subset_Flair, batch_size=batch_size, shuffle=True)
# multiprocessing_context="forkserver", persistent_workers=True, num_workers = 4

# %% [markdown]
# ## Define Convlution Autoencoder Structure

# %%
class ConvAutoencoder(nn.Module):
  def __init__(self):
    super().__init__()

    self.features = nn.Sequential(
      ## encoder layers ##
      # conv layer (depth from 1 --> 4), 3x3 kernels
      # Input 64 x 64
      nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding = 'same'), # 64 x 64
      nn.ReLU(),
      # pooling layer to reduce x-y dims by two; kernel and stride of 2
      nn.MaxPool2d(2), ## 32 x 32
      # conv layer (depth from 4 --> 8), 4x4 kernels
      nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding = 'same'), # 32 x 32
      nn.ReLU(),
      nn.MaxPool2d(2), # 16 x 16
      # conv layer (depth from 8 --> 12), 5x5 kernels
      nn.Conv2d(in_channels=8, out_channels=12, kernel_size=3, padding = 'same'), # ( 12 x ) 16 x 16
      nn.ReLU(),
      
      ## decoder layers ##
      # add transpose conv layers, with relu activation function
      nn.ConvTranspose2d(12, 6, kernel_size = 2, stride=2), # 32 x 32
      nn.ReLU(),
      nn.ConvTranspose2d(6, 1, kernel_size = 2, stride=2), # 64 x 64
      # output layer (with sigmoid for scaling from 0 to 1)
      # nn.Sigmoid()
    )
    
  def forward(self, x):
    x = x.view(int(np.prod(x.shape)/(64**2)), 1, 64, 64)
    x = self.features(x)
    # x = x.view(x.shape[0], -1)
    # x = torch.flatten(x, start_dim=1)
    return x

# %%
model_Flair = ConvAutoencoder().to(device)

print(f"The model has {count_parameters(model_Flair):,} trainable parameters.")
# Out:
# The model has 1,531 trainable parameters.

# %% [markdown]
# ## Loss function and Optimisation Methods

# %%
# Loss
# criterion = nn.CrossEntropyLoss() # Softmax + CrossEntropy
# criterion = nn.BCELoss()
criterion = torch.nn.BCEWithLogitsLoss()
criterion = criterion.to(device)

# Optim
optimizer = optim.Adam(model_Flair.parameters(), lr=1e-3, weight_decay=1e-5)

# %% [markdown]
# ## Model Training

# %%
train_losses_Flair, train_accs_Flair, valid_losses_Flair, valid_accs_Flair, train_losses_Flair_epochs, train_accs_Flair_epochs, valid_losses_Flair_epochs, valid_accs_Flair_epochs = model_training(N_EPOCHS,
                                                                                                                                                                                                    model_Flair,
                                                                                                                                                                                                    train_dataloader_Flair,
                                                                                                                                                                                                    val_dataloader_Flair,
                                                                                                                                                                                                    optimizer,
                                                                                                                                                                                                    criterion,
                                                                                                                                                                                                    device,
                                                                                                                                                                                                    './models/CA_Flair.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/40 -- Epoch Time: 159.41 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 30.52%
# Val -- Loss: 0.717, Acc: 30.56%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/40 -- Epoch Time: 159.27 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 30.51%
# Val -- Loss: 0.717, Acc: 30.43%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/40 -- Epoch Time: 161.84 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 30.27%
# Val -- Loss: 0.717, Acc: 30.05%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/40 -- Epoch Time: 153.08 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 29.67%
# Val -- Loss: 0.717, Acc: 29.19%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/40 -- Epoch Time: 155.95 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 28.34%
# Val -- Loss: 0.717, Acc: 27.21%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/40 -- Epoch Time: 152.78 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 25.42%
# Val -- Loss: 0.717, Acc: 23.58%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/40 -- Epoch Time: 163.13 s
# ---------------------------------
# Train -- Loss: 0.717, Acc: 22.77%
# Val -- Loss: 0.717, Acc: 23.38%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/40 -- Epoch Time: 159.01 s
# ---------------------------------
# Train -- Loss: 0.718, Acc: 23.91%
# Val -- Loss: 0.718, Acc: 24.70%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/40 -- Epoch Time: 158.71 s
# ---------------------------------
# Train -- Loss: 0.718, Acc: 25.07%
# Val -- Loss: 0.719, Acc: 24.09%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/40 -- Epoch Time: 158.33 s
# ---------------------------------
# Train -- Loss: 0.719, Acc: 10.85%
# Val -- Loss: 0.719, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/40 -- Epoch Time: 161.66 s
# ---------------------------------
# Train -- Loss: 0.719, Acc: 2.67%
# Val -- Loss: 0.719, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/40 -- Epoch Time: 157.69 s
# ---------------------------------
# Train -- Loss: 0.718, Acc: 2.67%
# Val -- Loss: 0.717, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/40 -- Epoch Time: 155.06 s
# ---------------------------------
# Train -- Loss: 0.716, Acc: 2.67%
# Val -- Loss: 0.714, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/40 -- Epoch Time: 158.03 s
# ---------------------------------
# Train -- Loss: 0.712, Acc: 2.67%
# Val -- Loss: 0.711, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/40 -- Epoch Time: 155.22 s
# ---------------------------------
# Train -- Loss: 0.709, Acc: 2.67%
# Val -- Loss: 0.708, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/40 -- Epoch Time: 154.99 s
# ---------------------------------
# Train -- Loss: 0.705, Acc: 2.67%
# Val -- Loss: 0.702, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/40 -- Epoch Time: 157.15 s
# ---------------------------------
# Train -- Loss: 0.698, Acc: 2.67%
# Val -- Loss: 0.695, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/40 -- Epoch Time: 155.51 s
# ---------------------------------
# Train -- Loss: 0.694, Acc: 2.67%
# Val -- Loss: 0.693, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/40 -- Epoch Time: 155.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 2.67%
# Val -- Loss: 0.693, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/40 -- Epoch Time: 155.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 2.67%
# Val -- Loss: 0.693, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/40 -- Epoch Time: 157.39 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 88.60%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/40 -- Epoch Time: 157.24 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/40 -- Epoch Time: 155.23 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/40 -- Epoch Time: 155.75 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/40 -- Epoch Time: 154.57 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/40 -- Epoch Time: 156.16 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/40 -- Epoch Time: 154.33 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/40 -- Epoch Time: 156.19 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/40 -- Epoch Time: 155.42 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/40 -- Epoch Time: 155.00 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/40 -- Epoch Time: 155.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/40 -- Epoch Time: 157.01 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/40 -- Epoch Time: 155.92 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/40 -- Epoch Time: 162.38 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/40 -- Epoch Time: 155.00 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/40 -- Epoch Time: 155.69 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/40 -- Epoch Time: 156.95 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/40 -- Epoch Time: 155.61 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/40 -- Epoch Time: 155.79 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/40 -- Epoch Time: 156.74 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# # Repeat for T1

# %%
class BraTSDataset_T1(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 't1', file_name + '_t1_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
dataset_T1 = BraTSDataset_T1(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %%
if USE_SEED:
    set_seed(SEED, torch.cuda.is_available(), torch.backends.mps.is_available())

# %%
train_subset_T1 = Subset(dataset_T1, train_indices)
val_subset_T1 = Subset(dataset_T1, val_indices)
test_subset_T1 = Subset(dataset_T1, test_indices)

# Create the subset DataLoader
train_dataloader_T1 = DataLoader(train_subset_T1, batch_size=batch_size, shuffle=True)
val_dataloader_T1 = DataLoader(val_subset_T1, batch_size=batch_size, shuffle=True)
test_dataloader_T1 = DataLoader(test_subset_T1, batch_size=batch_size, shuffle=True)

# %%
model_T1 = ConvAutoencoder().to(device)
criterion = torch.nn.BCEWithLogitsLoss()
criterion = criterion.to(device)
optimizer = optim.Adam(model_T1.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
# # Reset Model Parameters

# for layer in model.children():
#    if hasattr(layer, 'reset_parameters'):
#        layer.reset_parameters()

# optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
train_losses_T1, train_accs_T1, valid_losses_T1, valid_accs_T1, train_losses_T1_epochs, train_accs_T1_epochs, valid_losses_T1_epochs, valid_accs_T1_epochs = model_training(N_EPOCHS,
                                                                                                                                                                            model_T1,
                                                                                                                                                                            train_dataloader_T1,
                                                                                                                                                                            val_dataloader_T1,
                                                                                                                                                                            optimizer,
                                                                                                                                                                            criterion,
                                                                                                                                                                            device,
                                                                                                                                                                            './models/CA_T1.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/40 -- Epoch Time: 188.54 s
# ---------------------------------
# Train -- Loss: 0.694, Acc: 62.79%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/40 -- Epoch Time: 181.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/40 -- Epoch Time: 182.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/40 -- Epoch Time: 181.52 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/40 -- Epoch Time: 183.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/40 -- Epoch Time: 180.50 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/40 -- Epoch Time: 181.34 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/40 -- Epoch Time: 182.49 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/40 -- Epoch Time: 180.29 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/40 -- Epoch Time: 181.21 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/40 -- Epoch Time: 183.33 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/40 -- Epoch Time: 182.87 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/40 -- Epoch Time: 180.08 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/40 -- Epoch Time: 182.86 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/40 -- Epoch Time: 182.41 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/40 -- Epoch Time: 184.76 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/40 -- Epoch Time: 180.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/40 -- Epoch Time: 179.93 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/40 -- Epoch Time: 181.66 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/40 -- Epoch Time: 179.63 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/40 -- Epoch Time: 179.67 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/40 -- Epoch Time: 179.73 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/40 -- Epoch Time: 183.79 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/40 -- Epoch Time: 181.41 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/40 -- Epoch Time: 182.75 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/40 -- Epoch Time: 180.09 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/40 -- Epoch Time: 180.78 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/40 -- Epoch Time: 188.15 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/40 -- Epoch Time: 1269.09 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/40 -- Epoch Time: 187.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/40 -- Epoch Time: 196.39 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/40 -- Epoch Time: 269.25 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/40 -- Epoch Time: 237.10 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/40 -- Epoch Time: 240.97 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/40 -- Epoch Time: 243.05 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/40 -- Epoch Time: 239.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/40 -- Epoch Time: 247.75 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/40 -- Epoch Time: 238.22 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/40 -- Epoch Time: 246.73 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/40 -- Epoch Time: 636.83 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# # T1CE

# %%
class BraTSDataset_T1CE(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 't1ce', file_name + '_t1ce_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
dataset_T1CE = BraTSDataset_T1CE(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %%
if USE_SEED:
    set_seed(SEED, torch.cuda.is_available(), torch.backends.mps.is_available())

# %%
train_subset_T1CE = Subset(dataset_T1CE, train_indices)
val_subset_T1CE = Subset(dataset_T1CE, val_indices)
test_subset_T1CE = Subset(dataset_T1CE, test_indices)

# Create the subset DataLoader
train_dataloader_T1CE = DataLoader(train_subset_T1CE, batch_size=batch_size, shuffle=True)
val_dataloader_T1CE = DataLoader(val_subset_T1CE, batch_size=batch_size, shuffle=True)
test_dataloader_T1CE = DataLoader(test_subset_T1CE, batch_size=batch_size, shuffle=True)

# %%
model_T1ce = ConvAutoencoder().to(device)
criterion = torch.nn.BCEWithLogitsLoss()
criterion = criterion.to(device)
optimizer = optim.Adam(model_T1ce.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
# # Reset Model Parameters

# for layer in model.children():
#    if hasattr(layer, 'reset_parameters'):
#        layer.reset_parameters()

# optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
train_losses_T1CE, train_accs_T1CE, valid_losses_T1CE, valid_accs_T1CE, train_losses_T1CE_epochs, train_accs_T1CE_epochs, valid_losses_T1CE_epochs, valid_accs_T1CE_epochs = model_training(N_EPOCHS,
                                                                                                                                                                                            model_T1ce,
                                                                                                                                                                                            train_dataloader_T1CE,
                                                                                                                                                                                            val_dataloader_T1CE,
                                                                                                                                                                                            optimizer,
                                                                                                                                                                                            criterion,
                                                                                                                                                                                            device,
                                                                                                                                                                                            './models/CA_T1CE.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/40 -- Epoch Time: 193.56 s
# ---------------------------------
# Train -- Loss: 0.694, Acc: 62.80%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/40 -- Epoch Time: 232.17 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/40 -- Epoch Time: 267.98 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/40 -- Epoch Time: 1143.98 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/40 -- Epoch Time: 1055.54 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/40 -- Epoch Time: 1113.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/40 -- Epoch Time: 193.68 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/40 -- Epoch Time: 206.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/40 -- Epoch Time: 208.90 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/40 -- Epoch Time: 236.62 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/40 -- Epoch Time: 234.09 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/40 -- Epoch Time: 240.23 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/40 -- Epoch Time: 241.32 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/40 -- Epoch Time: 245.07 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/40 -- Epoch Time: 246.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/40 -- Epoch Time: 245.50 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/40 -- Epoch Time: 1648.07 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/40 -- Epoch Time: 190.98 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/40 -- Epoch Time: 1090.82 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/40 -- Epoch Time: 450.00 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/40 -- Epoch Time: 541.02 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/40 -- Epoch Time: 478.32 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/40 -- Epoch Time: 664.02 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/40 -- Epoch Time: 340.70 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/40 -- Epoch Time: 188.32 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/40 -- Epoch Time: 188.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/40 -- Epoch Time: 186.75 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/40 -- Epoch Time: 188.05 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/40 -- Epoch Time: 189.62 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/40 -- Epoch Time: 187.81 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/40 -- Epoch Time: 186.65 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/40 -- Epoch Time: 188.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/40 -- Epoch Time: 187.21 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/40 -- Epoch Time: 186.65 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/40 -- Epoch Time: 188.18 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/40 -- Epoch Time: 188.25 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/40 -- Epoch Time: 187.15 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/40 -- Epoch Time: 187.24 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/40 -- Epoch Time: 187.48 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/40 -- Epoch Time: 187.60 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# # T2

# %%
class BraTSDataset_T2(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 't2', file_name + '_t2_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
dataset_T2 = BraTSDataset_T2(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %%
if USE_SEED:
    set_seed(SEED, torch.cuda.is_available(), torch.backends.mps.is_available())

# %%
train_subset_T2 = Subset(dataset_T2, train_indices)
val_subset_T2 = Subset(dataset_T2, val_indices)
test_subset_T2 = Subset(dataset_T2, test_indices)

# Create the subset DataLoader
train_dataloader_T2 = DataLoader(train_subset_T2, batch_size=batch_size, shuffle=True)
val_dataloader_T2 = DataLoader(val_subset_T2, batch_size=batch_size, shuffle=True)
test_dataloader_T2 = DataLoader(test_subset_T2, batch_size=batch_size, shuffle=True)

# %%
model_T2 = ConvAutoencoder().to(device)
criterion = torch.nn.BCEWithLogitsLoss()
criterion = criterion.to(device)
optimizer = optim.Adam(model_T2.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
# # Reset Model Parameters

# for layer in model.children():
#    if hasattr(layer, 'reset_parameters'):
#        layer.reset_parameters()

# optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
train_losses_T2, train_accs_T2, valid_losses_T2, valid_accs_T2, train_losses_T2_epochs, train_accs_T2_epochs, valid_losses_T2_epochs, valid_accs_T2_epochs = model_training(N_EPOCHS,
                                                                                                                                                                            model_T2,
                                                                                                                                                                            train_dataloader_T2,
                                                                                                                                                                            val_dataloader_T2,
                                                                                                                                                                            optimizer,
                                                                                                                                                                            criterion,
                                                                                                                                                                            device,
                                                                                                                                                                            './models/CA_T2.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/40 -- Epoch Time: 197.45 s
# ---------------------------------
# Train -- Loss: 0.694, Acc: 62.81%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/40 -- Epoch Time: 183.88 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/40 -- Epoch Time: 182.31 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/40 -- Epoch Time: 184.35 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/40 -- Epoch Time: 177.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/40 -- Epoch Time: 176.01 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/40 -- Epoch Time: 179.95 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/40 -- Epoch Time: 178.83 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/40 -- Epoch Time: 176.87 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/40 -- Epoch Time: 178.23 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/40 -- Epoch Time: 177.83 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/40 -- Epoch Time: 176.87 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/40 -- Epoch Time: 175.79 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/40 -- Epoch Time: 176.90 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/40 -- Epoch Time: 180.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/40 -- Epoch Time: 175.76 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/40 -- Epoch Time: 178.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/40 -- Epoch Time: 176.72 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/40 -- Epoch Time: 176.72 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/40 -- Epoch Time: 177.14 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/40 -- Epoch Time: 176.82 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/40 -- Epoch Time: 176.78 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/40 -- Epoch Time: 176.78 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/40 -- Epoch Time: 184.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/40 -- Epoch Time: 177.08 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/40 -- Epoch Time: 178.41 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/40 -- Epoch Time: 183.07 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/40 -- Epoch Time: 180.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/40 -- Epoch Time: 180.49 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/40 -- Epoch Time: 180.46 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/40 -- Epoch Time: 179.26 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/40 -- Epoch Time: 180.55 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/40 -- Epoch Time: 179.74 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/40 -- Epoch Time: 181.21 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/40 -- Epoch Time: 180.57 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/40 -- Epoch Time: 184.43 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/40 -- Epoch Time: 186.63 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/40 -- Epoch Time: 188.81 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/40 -- Epoch Time: 192.33 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/40 -- Epoch Time: 197.43 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# ## Save train, val and test indices, losses and accuracies

# %%
os.makedirs('./results', exist_ok=True)
for scan_type in ['Flair', 'T1', 'T1CE', 'T2']:
    csv_name = f'./results/CA_{scan_type}.csv'
    pd.DataFrame({
        'train_losses': eval(f'train_losses_{scan_type}'),
        'train_accs': eval(f'train_accs_{scan_type}'),
        'valid_losses': eval(f'valid_losses_{scan_type}'),
        'valid_accs': eval(f'valid_accs_{scan_type}')
    }).to_csv(csv_name, index=False)

# %%
train_losses_epochs = [pd.DataFrame(train_losses_Flair_epochs).values.flatten(),
                        pd.DataFrame(train_losses_T1_epochs).values.flatten(),
                        pd.DataFrame(train_losses_T1CE_epochs).values.flatten(),
                        pd.DataFrame(train_losses_T2_epochs).values.flatten()]
train_accs_epochs = [pd.DataFrame(train_accs_Flair_epochs).values.flatten(),
                        pd.DataFrame(train_accs_T1_epochs).values.flatten(),
                        pd.DataFrame(train_accs_T1CE_epochs).values.flatten(),
                        pd.DataFrame(train_accs_T2_epochs).values.flatten()]
valid_losses_epochs = [pd.DataFrame(valid_losses_Flair_epochs).values.flatten(),
                        pd.DataFrame(valid_losses_T1_epochs).values.flatten(),
                        pd.DataFrame(valid_losses_T1CE_epochs).values.flatten(),
                        pd.DataFrame(valid_losses_T2_epochs).values.flatten()]
valid_accs_epochs = [pd.DataFrame(valid_accs_Flair_epochs).values.flatten(),
                        pd.DataFrame(valid_accs_T1_epochs).values.flatten(),
                        pd.DataFrame(valid_accs_T1CE_epochs).values.flatten(),
                        pd.DataFrame(valid_accs_T2_epochs).values.flatten()]

# %%
pd.DataFrame(np.vstack(train_losses_epochs), index = ['Flair', 'T1', 'T1CE', 'T2']).to_csv('./results/CA_train_losses_epochs.csv', index=True)
pd.DataFrame(np.vstack(train_accs_epochs), index = ['Flair', 'T1', 'T1CE', 'T2']).to_csv('./results/CA_train_accs_epochs.csv', index=True)
pd.DataFrame(np.vstack(valid_losses_epochs), index = ['Flair', 'T1', 'T1CE', 'T2']).to_csv('./results/CA_valid_losses_epochs.csv', index=True)
pd.DataFrame(np.vstack(valid_accs_epochs), index = ['Flair', 'T1', 'T1CE', 'T2']).to_csv('./results/CA_valid_accs_epochs.csv', index=True)
