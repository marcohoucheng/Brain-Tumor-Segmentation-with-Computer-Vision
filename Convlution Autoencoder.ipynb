# %%
N_EPOCHS = 50
batch_size = 32

# %% [markdown]
# # Flair

# %% [markdown]
# ## Setup

# %%
import os, random, time
import numpy as np
import nibabel as nib
import cv2
import matplotlib.pyplot as plt

# Pytorch functions
import torch
# Neural network layers
import torch.nn as nn
import torch.nn.functional as F
# Optimizer
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, Subset
# Torchvision library
from torchvision import transforms

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# For results
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from torchsummary import summary

from utilities import *

# %%
# Device configuration
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
   device = torch.device('mps')
else:
    device = torch.device('cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# mps

# %%
def set_seed(seed, use_cuda = True, use_mps = False):
    """
    Set SEED for PyTorch reproducibility
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if use_cuda:
        torch.cuda.manual_seed_all(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    if use_mps:
        torch.mps.manual_seed(seed)

SEED = 44

USE_SEED = True

if USE_SEED:
    set_seed(SEED, torch.cuda.is_available(), torch.backends.mps.is_available())

# %% [markdown]
# ## Define Custom Dataset

# %%
class BraTSDataset_Flair(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 'flair', file_name + '_flair_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
class BinariseLabel(object):
    def __call__(self, sample):
        image, label = sample
        new_label = np.sign(label)
        return image, new_label

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""
    def __call__(self, sample):
        image, label = sample

        # numpy image: H x W x C
        # torch image: C x H x W
        # image = image.transpose((2, 0, 1))
        return torch.from_numpy(image), torch.from_numpy(label)

# %%
dataset = BraTSDataset_Flair(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %% [markdown]
# ## Train Test Split

# %%
dataset_size = int(len(dataset)/155)
dataset_indices = list(range(dataset_size))

train_indices, test_indices = train_test_split(dataset_indices, test_size=0.1, random_state=SEED)
train_indices, val_indices = train_test_split(train_indices, test_size=0.22, random_state=SEED)

tmp_list = [[],[],[]]
for i, ind_list in enumerate([train_indices, val_indices, test_indices]):
    for ind in ind_list:
        for j in range(155):
            tmp_list[i].append(ind*155 + j)
train_indices, val_indices, test_indices = tmp_list

train_subset = Subset(dataset, train_indices)
val_subset = Subset(dataset, val_indices)
test_subset = Subset(dataset, test_indices)

# Create the subset DataLoader
train_dataloader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_subset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_subset, batch_size=batch_size, shuffle=True)
# multiprocessing_context="forkserver", persistent_workers=True, num_workers = 4

# %% [markdown]
# ## Define CNN Structure

# %%
class CNN(nn.Module):
  def __init__(self):
    super().__init__()

    self.features = nn.Sequential(
      ## encoder layers ##
      # conv layer (depth from 1 --> 4), 3x3 kernels
      # Input 64 x 64
      nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding = 'same'), # 64 x 64
      nn.ReLU(),
      # pooling layer to reduce x-y dims by two; kernel and stride of 2
      nn.MaxPool2d(2), ## 32 x 32
      # conv layer (depth from 4 --> 8), 4x4 kernels
      nn.Conv2d(in_channels=4, out_channels=8, kernel_size=3, padding = 'same'), # 32 x 32
      nn.ReLU(),
      nn.MaxPool2d(2), # 16 x 16
      # conv layer (depth from 8 --> 12), 5x5 kernels
      nn.Conv2d(in_channels=8, out_channels=12, kernel_size=3, padding = 'same'), # ( 12 x ) 16 x 16
      nn.ReLU(),
      
      ## decoder layers ##
      # add transpose conv layers, with relu activation function
      nn.ConvTranspose2d(12, 6, kernel_size = 2, stride=2), # 32 x 32
      nn.ReLU(),
      nn.ConvTranspose2d(6, 1, kernel_size = 2, stride=2), # 64 x 64
      # output layer (with sigmoid for scaling from 0 to 1)
      # nn.Sigmoid()
    )
    
  def forward(self, x):
    x = x.view(int(np.prod(x.shape)/(64**2)), 1, 64, 64)
    x = self.features(x)
    # x = x.view(x.shape[0], -1)
    # x = torch.flatten(x, start_dim=1)
    return x

# %%
model = CNN().to(device)

print(f"The model has {count_parameters(model):,} trainable parameters.")
# Out:
# The model has 1,531 trainable parameters.

# %% [markdown]
# ## Loss function and Optimisation Methods

# %%
# Loss
# criterion = nn.CrossEntropyLoss() # Softmax + CrossEntropy
# criterion = nn.BCELoss()
criterion = torch.nn.BCEWithLogitsLoss()
criterion = criterion.to(device)

# Optim
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)

# %% [markdown]
# ## Model Training

# %%
train_losses, train_accs, valid_losses, valid_accs = model_training(N_EPOCHS,
                                                                    model,
                                                                    train_dataloader,
                                                                    val_dataloader,
                                                                    optimizer,
                                                                    criterion,
                                                                    device,
                                                                    'CA_Flair.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/50 -- Epoch Time: 168.52 s
# ---------------------------------
# Train -- Loss: 0.723, Acc: 17.60%
# Val -- Loss: 0.722, Acc: 17.55%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/50 -- Epoch Time: 172.52 s
# ---------------------------------
# Train -- Loss: 0.723, Acc: 17.08%
# Val -- Loss: 0.722, Acc: 16.33%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/50 -- Epoch Time: 170.75 s
# ---------------------------------
# Train -- Loss: 0.723, Acc: 14.09%
# Val -- Loss: 0.723, Acc: 10.72%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/50 -- Epoch Time: 170.19 s
# ---------------------------------
# Train -- Loss: 0.723, Acc: 4.08%
# Val -- Loss: 0.723, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/50 -- Epoch Time: 162.35 s
# ---------------------------------
# Train -- Loss: 0.723, Acc: 2.67%
# Val -- Loss: 0.722, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/50 -- Epoch Time: 163.26 s
# ---------------------------------
# Train -- Loss: 0.721, Acc: 2.67%
# Val -- Loss: 0.718, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/50 -- Epoch Time: 162.97 s
# ---------------------------------
# Train -- Loss: 0.715, Acc: 2.67%
# Val -- Loss: 0.711, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/50 -- Epoch Time: 161.82 s
# ---------------------------------
# Train -- Loss: 0.705, Acc: 2.67%
# Val -- Loss: 0.698, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/50 -- Epoch Time: 163.21 s
# ---------------------------------
# Train -- Loss: 0.694, Acc: 2.67%
# Val -- Loss: 0.693, Acc: 2.78%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/50 -- Epoch Time: 161.28 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 27.47%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/50 -- Epoch Time: 166.57 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/50 -- Epoch Time: 165.02 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/50 -- Epoch Time: 164.88 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/50 -- Epoch Time: 164.98 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/50 -- Epoch Time: 164.05 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/50 -- Epoch Time: 162.61 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/50 -- Epoch Time: 162.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/50 -- Epoch Time: 162.83 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/50 -- Epoch Time: 163.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/50 -- Epoch Time: 162.53 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/50 -- Epoch Time: 162.58 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/50 -- Epoch Time: 163.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/50 -- Epoch Time: 163.44 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/50 -- Epoch Time: 162.88 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/50 -- Epoch Time: 162.48 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/50 -- Epoch Time: 162.53 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/50 -- Epoch Time: 166.28 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/50 -- Epoch Time: 163.26 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/50 -- Epoch Time: 166.64 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/50 -- Epoch Time: 164.96 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/50 -- Epoch Time: 167.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/50 -- Epoch Time: 165.05 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/50 -- Epoch Time: 168.08 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/50 -- Epoch Time: 168.86 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/50 -- Epoch Time: 165.71 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/50 -- Epoch Time: 163.87 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/50 -- Epoch Time: 165.99 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/50 -- Epoch Time: 163.97 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/50 -- Epoch Time: 161.70 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/50 -- Epoch Time: 160.88 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 41/50 -- Epoch Time: 161.72 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 42/50 -- Epoch Time: 160.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 43/50 -- Epoch Time: 161.78 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 44/50 -- Epoch Time: 160.67 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 45/50 -- Epoch Time: 160.81 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 46/50 -- Epoch Time: 162.36 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 47/50 -- Epoch Time: 160.68 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 48/50 -- Epoch Time: 161.64 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 49/50 -- Epoch Time: 160.73 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 50/50 -- Epoch Time: 161.54 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# # Repeat for T1

# %%
class BraTSDataset_T1(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 't1', file_name + '_t1_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
dataset_T1 = BraTSDataset_T1(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %%
train_subset_T1 = Subset(dataset_T1, train_indices)
val_subset_T1 = Subset(dataset_T1, val_indices)
test_subset_T1 = Subset(dataset_T1, test_indices)

# Create the subset DataLoader
train_dataloader_T1 = DataLoader(train_subset_T1, batch_size=batch_size, shuffle=True)
val_dataloader_T1 = DataLoader(val_subset_T1, batch_size=batch_size, shuffle=True)
test_dataloader_T1 = DataLoader(test_subset_T1, batch_size=batch_size, shuffle=True)

# %%
# Reset Model

for layer in model.children():
   if hasattr(layer, 'reset_parameters'):
       layer.reset_parameters()

# %%
train_losses_T1, train_accs_T1, valid_losses_T1, valid_accs_T1 = model_training(N_EPOCHS,
                                                                    model,
                                                                    train_dataloader_T1,
                                                                    val_dataloader_T1,
                                                                    optimizer,
                                                                    criterion,
                                                                    device,
                                                                    'CA_T1.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/50 -- Epoch Time: 193.94 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/50 -- Epoch Time: 181.80 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/50 -- Epoch Time: 176.92 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/50 -- Epoch Time: 178.02 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/50 -- Epoch Time: 177.22 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/50 -- Epoch Time: 178.95 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/50 -- Epoch Time: 180.48 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/50 -- Epoch Time: 177.81 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/50 -- Epoch Time: 177.94 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/50 -- Epoch Time: 179.74 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/50 -- Epoch Time: 181.70 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/50 -- Epoch Time: 181.58 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/50 -- Epoch Time: 181.03 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/50 -- Epoch Time: 180.66 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/50 -- Epoch Time: 181.43 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/50 -- Epoch Time: 185.10 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/50 -- Epoch Time: 183.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/50 -- Epoch Time: 179.73 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/50 -- Epoch Time: 183.23 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/50 -- Epoch Time: 179.25 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/50 -- Epoch Time: 181.27 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/50 -- Epoch Time: 180.16 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/50 -- Epoch Time: 179.41 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/50 -- Epoch Time: 179.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/50 -- Epoch Time: 179.53 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/50 -- Epoch Time: 179.62 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/50 -- Epoch Time: 180.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/50 -- Epoch Time: 179.51 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/50 -- Epoch Time: 180.77 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/50 -- Epoch Time: 179.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/50 -- Epoch Time: 179.49 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/50 -- Epoch Time: 180.20 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/50 -- Epoch Time: 179.62 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/50 -- Epoch Time: 183.20 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/50 -- Epoch Time: 181.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/50 -- Epoch Time: 180.42 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/50 -- Epoch Time: 183.25 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/50 -- Epoch Time: 183.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/50 -- Epoch Time: 181.89 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/50 -- Epoch Time: 182.46 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 41/50 -- Epoch Time: 182.18 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 42/50 -- Epoch Time: 183.41 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 43/50 -- Epoch Time: 181.65 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 44/50 -- Epoch Time: 182.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 45/50 -- Epoch Time: 180.66 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 46/50 -- Epoch Time: 188.82 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 47/50 -- Epoch Time: 185.49 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 48/50 -- Epoch Time: 186.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 49/50 -- Epoch Time: 186.61 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 50/50 -- Epoch Time: 183.57 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# # T1CE

# %%
class BraTSDataset_T1CE(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 't1', file_name + '_t1_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
dataset_T1CE = BraTSDataset_T1CE(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %%
train_subset_T1CE = Subset(dataset_T1CE, train_indices)
val_subset_T1CE = Subset(dataset_T1CE, val_indices)
test_subset_T1CE = Subset(dataset_T1CE, test_indices)

# Create the subset DataLoader
train_dataloader_T1CE = DataLoader(train_subset_T1CE, batch_size=batch_size, shuffle=True)
val_dataloader_T1CE = DataLoader(val_subset_T1CE, batch_size=batch_size, shuffle=True)
test_dataloader_T1CE = DataLoader(test_subset_T1CE, batch_size=batch_size, shuffle=True)

# %%
# Reset Model

for layer in model.children():
   if hasattr(layer, 'reset_parameters'):
       layer.reset_parameters()

# %%
train_losses_T1CE, train_accs_T1CE, valid_losses_T1CE, valid_accs_T1CE = model_training(N_EPOCHS,
                                                                    model,
                                                                    train_dataloader_T1CE,
                                                                    val_dataloader_T1CE,
                                                                    optimizer,
                                                                    criterion,
                                                                    device,
                                                                    'CA_T1CE.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/50 -- Epoch Time: 185.50 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/50 -- Epoch Time: 183.63 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/50 -- Epoch Time: 183.48 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/50 -- Epoch Time: 185.14 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/50 -- Epoch Time: 184.89 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/50 -- Epoch Time: 184.69 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/50 -- Epoch Time: 186.23 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/50 -- Epoch Time: 182.41 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/50 -- Epoch Time: 181.12 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/50 -- Epoch Time: 181.40 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/50 -- Epoch Time: 182.11 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/50 -- Epoch Time: 185.44 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/50 -- Epoch Time: 181.94 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/50 -- Epoch Time: 183.03 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/50 -- Epoch Time: 181.86 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/50 -- Epoch Time: 183.86 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/50 -- Epoch Time: 183.68 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/50 -- Epoch Time: 182.06 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/50 -- Epoch Time: 185.44 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/50 -- Epoch Time: 185.63 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/50 -- Epoch Time: 184.49 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/50 -- Epoch Time: 183.99 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/50 -- Epoch Time: 183.51 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/50 -- Epoch Time: 184.19 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/50 -- Epoch Time: 185.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/50 -- Epoch Time: 184.98 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/50 -- Epoch Time: 184.18 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/50 -- Epoch Time: 184.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/50 -- Epoch Time: 185.13 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/50 -- Epoch Time: 186.52 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/50 -- Epoch Time: 182.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/50 -- Epoch Time: 183.37 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/50 -- Epoch Time: 183.36 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/50 -- Epoch Time: 183.45 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/50 -- Epoch Time: 183.08 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/50 -- Epoch Time: 183.49 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/50 -- Epoch Time: 185.78 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/50 -- Epoch Time: 182.90 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/50 -- Epoch Time: 182.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/50 -- Epoch Time: 182.64 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 41/50 -- Epoch Time: 184.50 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 42/50 -- Epoch Time: 183.32 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 43/50 -- Epoch Time: 186.05 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 44/50 -- Epoch Time: 186.89 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 45/50 -- Epoch Time: 184.15 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 46/50 -- Epoch Time: 185.85 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 47/50 -- Epoch Time: 184.90 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 48/50 -- Epoch Time: 184.03 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 49/50 -- Epoch Time: 190.00 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 50/50 -- Epoch Time: 188.69 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%

# %% [markdown]
# # T2

# %%
class BraTSDataset_T2(Dataset):
    def __init__(self, image_path = r'./BraTS/BraTS2021_Training_Data_2D', transform=None):
        'Initialisation'
        self.image_path = image_path
        self.folders_name = [folder for folder in os.listdir(self.image_path) if folder != '.DS_Store']
        self.transform = transform

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.folders_name) * 155

    def __getitem__(self, index):
        'Generates one sample of data'

        # Determine the image index and the RGB layer
        image_idx = index // 155
        layer_idx = index % 155

        # Select sample
        file_name = self.folders_name[image_idx]
        
        path_img = os.path.join(self.image_path, file_name, 't1', file_name + '_t1_' + str(layer_idx+1) + '.npy')
        image = np.load(path_img).astype(np.float32)

        path_label = os.path.join(self.image_path, file_name, 'seg', file_name + '_seg_' + str(layer_idx+1) + '.npy')
        label = np.load(path_label)
        
        if self.transform:
            image, label = self.transform([image, label])
        return image, label

# %%
dataset_T2 = BraTSDataset_T2(image_path = r'./BraTS/BraTS2021_Training_Data_2D',
                                    transform=transforms.Compose([
                                        BinariseLabel(),
                                        ToTensor()
                                    ]))

# %%
train_subset_T2 = Subset(dataset_T2, train_indices)
val_subset_T2 = Subset(dataset_T2, val_indices)
test_subset_T2 = Subset(dataset_T2, test_indices)

# Create the subset DataLoader
train_dataloader_T2 = DataLoader(train_subset_T2, batch_size=batch_size, shuffle=True)
val_dataloader_T2 = DataLoader(val_subset_T2, batch_size=batch_size, shuffle=True)
test_dataloader_T2 = DataLoader(test_subset_T2, batch_size=batch_size, shuffle=True)

# %%
# Reset Model

for layer in model.children():
   if hasattr(layer, 'reset_parameters'):
       layer.reset_parameters()

# %%
train_losses_T2, train_accs_T2, valid_losses_T2, valid_accs_T2 = model_training(N_EPOCHS,
                                                                    model,
                                                                    train_dataloader_T2,
                                                                    val_dataloader_T2,
                                                                    optimizer,
                                                                    criterion,
                                                                    device,
                                                                    'CA_T2.pt')
# Out:
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 1/50 -- Epoch Time: 188.67 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 2/50 -- Epoch Time: 189.31 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 3/50 -- Epoch Time: 186.73 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 4/50 -- Epoch Time: 187.81 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 5/50 -- Epoch Time: 188.46 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 6/50 -- Epoch Time: 187.92 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 7/50 -- Epoch Time: 185.52 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 8/50 -- Epoch Time: 186.58 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 9/50 -- Epoch Time: 186.11 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 10/50 -- Epoch Time: 182.55 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 11/50 -- Epoch Time: 184.64 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 12/50 -- Epoch Time: 185.24 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 13/50 -- Epoch Time: 183.44 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 14/50 -- Epoch Time: 192.83 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 15/50 -- Epoch Time: 190.91 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 16/50 -- Epoch Time: 188.86 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 17/50 -- Epoch Time: 189.03 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 18/50 -- Epoch Time: 189.84 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 19/50 -- Epoch Time: 188.47 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 20/50 -- Epoch Time: 187.20 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 21/50 -- Epoch Time: 188.93 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 22/50 -- Epoch Time: 189.81 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 23/50 -- Epoch Time: 189.68 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 24/50 -- Epoch Time: 185.29 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 25/50 -- Epoch Time: 186.34 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 26/50 -- Epoch Time: 185.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 27/50 -- Epoch Time: 185.46 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 28/50 -- Epoch Time: 189.90 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 29/50 -- Epoch Time: 186.92 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 30/50 -- Epoch Time: 187.78 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 31/50 -- Epoch Time: 188.77 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 32/50 -- Epoch Time: 185.04 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 33/50 -- Epoch Time: 186.04 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 34/50 -- Epoch Time: 186.02 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 35/50 -- Epoch Time: 188.64 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 36/50 -- Epoch Time: 186.05 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 37/50 -- Epoch Time: 185.03 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 38/50 -- Epoch Time: 186.77 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 39/50 -- Epoch Time: 190.11 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 40/50 -- Epoch Time: 186.93 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 41/50 -- Epoch Time: 185.50 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 42/50 -- Epoch Time: 186.27 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 43/50 -- Epoch Time: 189.64 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 44/50 -- Epoch Time: 186.51 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 45/50 -- Epoch Time: 187.76 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 46/50 -- Epoch Time: 187.85 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 47/50 -- Epoch Time: 188.48 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 48/50 -- Epoch Time: 185.52 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 49/50 -- Epoch Time: 186.30 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
# 100.0 % loaded in this epoch for evaluation.
# Epoch: 50/50 -- Epoch Time: 187.56 s
# ---------------------------------
# Train -- Loss: 0.693, Acc: 97.33%
# Val -- Loss: 0.693, Acc: 97.22%
